# %% [markdown]
# # echartsy Examples
#
# A collection of examples ranging from simple to complex, demonstrating
# the full power of echartsy's matplotlib-style API for Apache ECharts.
#
# ---

# %%
# %pip install --upgrade echartsy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import echartsy as ec
import pandas as pd
import numpy as np

# Configure rendering engine
# Options: "jupyter" (inline widget), "python" (browser popup), "streamlit"
ec.config(engine="jupyter")

print(f"echartsy v{ec.__version__} ready!")
# Out:
# echartsy v0.5.2 ready!

# %% [markdown]
# ---
# ## 1. Simple Bar Chart
#
# The most basic chart — just pass a DataFrame with x and y columns.

# %%
df_fruit = pd.DataFrame({
    "Fruit": ["Apples", "Bananas", "Cherries", "Dates", "Elderberries"],
    "Sales": [120, 95, 78, 42, 63]
})

fig = ec.figure(renderer='svg')
fig.bar(df_fruit, x="Fruit", y="Sales")
fig.title("Fruit Sales")
fig.pie(df=df_fruit,names='Fruit',values='Sales',center=['85%','25%'],radius=['10%', '30%'], label_font_size=5)
fig.legend(top=40)
fig.margins(top=40)
fig.toolbox()
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="420px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 2. Simple Line Chart
#
# Use `.plot()` just like `plt.plot()` — with optional smoothing.

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
          "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

df_temp = pd.DataFrame({
    "Month": months,
    "Temperature": [5, 7, 12, 18, 23, 28, 31, 30, 25, 18, 11, 6]
})

fig = ec.figure(renderer="svg", height="400px")
fig.plot(df_temp, x="Month", y="Temperature", smooth=True, labels=True)
fig.title("Average Monthly Temperature")
fig.ylabel("Temp (°C)")
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="420px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 3. Pie / Donut Chart
#
# Pie charts use `names` and `values` instead of x/y.

# %%
df_market = pd.DataFrame({
    "Browser": ["Chrome", "Safari", "Firefox", "Edge", "Other"],
    "Share": [65.7, 18.2, 6.3, 5.1, 4.7]
})

fig = ec.figure(renderer="svg", height="450px")
fig.pie(df_market, names="Browser", values="Share", inner_radius="40%", label_font_size=12)
fig.title("Browser Market Share 2025")
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="470px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 4. Scatter Plot
#
# Scatter plots with optional `color` and `size` encoding.

# %%
np.random.seed(42)
n = 80
df_scatter = pd.DataFrame({
    "Height": np.random.normal(170, 10, n),
    "Weight": np.random.normal(70, 12, n),
    "Gender": np.random.choice(["Male", "Female"], n)
})

fig = ec.figure(renderer="svg", height="450px")
fig.scatter(df_scatter, x="Height", y="Weight", color="Gender")
fig.title("Height vs Weight")
fig.xlabel("Height (cm)")
fig.ylabel("Weight (kg)")
fig.legend(top=40)
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="470px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 5. Grouped Bar Chart with `hue`
#
# Pass a `hue` column to automatically create grouped (side-by-side) bars.

# %%
df_revenue = pd.DataFrame({
    "Quarter": ["Q1", "Q2", "Q3", "Q4"] * 3,
    "Revenue": [120, 145, 160, 180, 90, 110, 130, 155, 60, 80, 95, 110],
    "Region": ["North"] * 4 + ["South"] * 4 + ["West"] * 4
})

fig = ec.figure(renderer="svg", height="450px")
fig.bar(df_revenue, x="Quarter", y="Revenue", hue="Region")
fig.title("Quarterly Revenue by Region")
fig.ylabel("Revenue ($K)")
fig.legend(top=40)
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="470px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 6. Stacked Bar Chart
#
# Combine `hue` with `stack=True` to stack the bars.

# %%
fig = ec.figure(renderer="svg", height="450px")
fig.bar(df_revenue, x="Quarter", y="Revenue", hue="Region",
        stack=True, labels=True)
fig.palette(ec.PALETTE_RUSTY)
fig.title("Stacked Revenue by Region")
fig.ylabel("Revenue ($K)")
fig.legend(top=40)
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="470px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 7. Histogram
#
# Visualize the distribution of a single column.

# %%
np.random.seed(7)
df_scores = pd.DataFrame({"Score": np.random.normal(72, 15, 500)})

fig = ec.figure(renderer="svg", height="400px")
fig.hist(df_scores, column="Score", bins=10)
fig.title("Exam Score Distribution")
fig.xlabel("Score")
fig.ylabel("Count")
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="420px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 8. Area Chart
#
# Line charts become area charts with `area=True`.

# %%
df_traffic = pd.DataFrame({
    "Hour": list(range(24)),
    "Users": [12, 8, 5, 3, 4, 8, 25, 60, 95, 120, 110, 105,
              115, 108, 100, 98, 112, 130, 95, 70, 50, 35, 22, 15],
})

fig = ec.figure(renderer="svg", height="400px")
fig.plot(df_traffic, x="Hour", y="Users", smooth=True,
         area=True, area_opacity=0.3)
fig.title("Website Traffic — 24hr")
fig.xlabel("Hour of Day")
fig.ylabel("Active Users")
fig.legend(top=40)
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="420px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 9. Horizontal Bar Chart
#
# Set `orient="h"` for horizontal bars — great for long category names.

# %%
df_lang = pd.DataFrame({
    "Language": ["Python", "JavaScript", "TypeScript", "Java", "C#",
                 "C++", "Go", "Rust", "Kotlin", "Swift"],
    "Popularity": [100, 95, 72, 68, 60, 55, 48, 42, 38, 35]
})

fig = ec.figure(renderer="svg", height="450px")
fig.bar(df_lang, x="Language", y="Popularity", orient="h",
        gradient=True, gradient_colors=("#83bff6", "#188df0"))
fig.title("Programming Language Popularity")
fig.legend(top=40)
fig.margins(top=70)
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="470px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 10. Multi-series: Bar + Line Overlay (Dual Axis)
#
# Combine bar and line on the same chart using `axis=1` for the secondary y-axis.

# %%
df_sales = pd.DataFrame({
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
    "Revenue": [250, 310, 280, 400, 520, 480],
})

df_growth = pd.DataFrame({
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
    "GrowthRate": [5.2, 8.1, 6.5, 12.3, 18.7, 15.0],
})

fig = ec.figure(renderer="svg", height="500px")
fig.bar(df_sales, x="Month", y="Revenue", labels=True)
fig.plot(df_growth, x="Month", y="GrowthRate", smooth=True, axis=1)
fig.title("Revenue & Growth Rate")
fig.ylabel("Revenue ($K)")
fig.legend(top=40)
fig.ylabel_right("Growth %")
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="520px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 11. Radar Chart
#
# Compare multi-dimensional profiles side by side.

# %%
indicators = [
    {"name": "Attack", "max": 100},
    {"name": "Defense", "max": 100},
    {"name": "Speed", "max": 100},
    {"name": "Stamina", "max": 100},
    {"name": "Magic", "max": 100},
    {"name": "Intelligence", "max": 100},
]

data = [
    [90, 60, 80, 70, 40, 55],   # Warrior
    [30, 40, 50, 60, 95, 90],   # Mage
    [70, 50, 95, 80, 20, 65],   # Rogue
]

fig = ec.figure(renderer="svg", height="500px")
fig.radar(indicators, data, series_names=["Warrior", "Mage", "Rogue"])
fig.title("Character Class Comparison")
fig.palette(ec.PALETTE_CLINICAL)
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="520px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 12. Heatmap
#
# Visualize a matrix of values — great for correlations or schedules.

# %%
days = ["Mon", "Tue", "Wed", "Thu", "Fri"]
hours = ["9am", "10am", "11am", "12pm", "1pm", "2pm", "3pm", "4pm"]

np.random.seed(123)
rows = []
for d in days:
    for h in hours:
        rows.append({"Day": d, "Hour": h, "Emails": np.random.randint(2, 50)})

df_heatmap = pd.DataFrame(rows)

fig = ec.figure(renderer="svg", height="450px")
fig.heatmap(df_heatmap, x="Hour", y="Day", value="Emails")
fig.title("Emails Received per Hour")
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="470px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 13. Funnel Chart
#
# Classic conversion funnel visualization.

# %%
df_funnel = pd.DataFrame({
    "Stage": ["Visitors", "Sign-ups", "Trial", "Paid", "Enterprise"],
    "Count": [10000, 3200, 1400, 600, 120]
})

fig = ec.figure(renderer="svg", height="450px")
fig.funnel(df_funnel, names="Stage", values="Count")
fig.title("Conversion Funnel")
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="470px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 14. Treemap
#
# Hierarchical data as nested rectangles. Pass `path` as a list of columns
# from broadest to most specific.

# %%
df_tree = pd.DataFrame({
    "Category": ["Electronics", "Electronics", "Electronics",
                 "Clothing", "Clothing", "Clothing",
                 "Food", "Food"],
    "SubCategory": ["Phones", "Laptops", "Tablets",
                    "Shirts", "Pants", "Shoes",
                    "Fruit", "Dairy"],
    "Sales": [500, 420, 180, 300, 250, 200, 150, 100]
})

fig = ec.figure(renderer="svg", height="500px")
fig.treemap(df_tree, path=["Category", "SubCategory"], value="Sales", roam=False)
fig.title("Sales by Category")
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="520px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 15. Sankey Diagram
#
# Visualize flow between stages. `levels` defines the columns in order.

# %%
df_flow = pd.DataFrame({
    "Source": ["Organic", "Organic", "Paid", "Paid", "Referral", "Referral"],
    "Channel": ["Landing Page A", "Landing Page B",
                "Landing Page A", "Landing Page B",
                "Landing Page A", "Landing Page B"],
    "Outcome": ["Converted", "Bounced", "Converted", "Bounced",
                "Converted", "Bounced"],
    "Users": [350, 150, 200, 300, 180, 70]
})

fig = ec.figure(renderer="svg", height="500px")
fig.sankey(df_flow, levels=["Source", "Channel", "Outcome"], value="Users",
           layout='orthogonal',emphasis=ec.SankeyEmphasis(blur_scope='series',focus='series',))
fig.title("User Flow: Source → Page → Outcome")
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="520px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 16. Box Plot
#
# Statistical distribution comparison across categories.

# %%
np.random.seed(99)
df_box = pd.DataFrame({
    "Department": np.repeat(["Engineering", "Marketing", "Sales", "Design"], 50),
    "Salary": np.concatenate([
        np.random.normal(120, 20, 50),
        np.random.normal(90, 15, 50),
        np.random.normal(85, 25, 50),
        np.random.normal(95, 18, 50),
    ])
})

fig = ec.figure(renderer="svg", height="450px")
fig.boxplot(df_box, x="Department", y="Salary")
fig.title("Salary Distribution by Department")
fig.ylabel("Salary ($K)")
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="470px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 17. Style Presets & Dark Theme
#
# Apply built-in style presets to change the look and feel. Combine with
# ECharts' `theme="dark"` for a full dark mode experience.

# %%
# Reuse df_revenue from Example 5
fig = ec.figure(renderer="svg", height="500px", theme="dark", style=ec.StylePreset.DASHBOARD_DARK)
fig.bar(df_revenue, x="Quarter", y="Revenue", hue="Region",
        stack=True, border_radius=6)
fig.title("Revenue by Region (Dark Mode)")
fig.ylabel("Revenue ($K)")
fig.toolbox()
fig.legend(top=40)
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="520px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 18. Custom Palette & Gradient Bars
#
# Fully customize the color palette or apply gradients to bars.

# %%
fig = ec.figure(renderer="svg", height="450px")
fig.bar(df_fruit, x="Fruit", y="Sales",
        gradient=True, gradient_colors=("#667eea", "#764ba2"),
        labels=True, border_radius=8)
fig.title("Fruit Sales (Gradient)")
fig.ylabel("Units Sold")
fig.palette(["#667eea", "#764ba2", "#f093fb", "#f5576c", "#4facfe"])
fig.grid(show=True)
fig.legend(top=40)
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="470px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 19. Multi-Line with Hue & Area
#
# Plot multiple series from a single DataFrame using `hue`.

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
df_multi = pd.DataFrame({
    "Month": months * 3,
    "Visitors": [100, 120, 150, 200, 180, 210,
                 80, 95, 120, 160, 140, 170,
                 60, 70, 90, 110, 100, 130],
    "Source": ["Organic"] * 6 + ["Paid"] * 6 + ["Social"] * 6
})

fig = ec.figure(renderer="svg", height="450px")
fig.plot(df_multi, x="Month", y="Visitors", hue="Source",
         smooth=True, area=True, area_opacity=0.15)
fig.title("Traffic by Source")
fig.ylabel("Visitors (K)")
fig.legend(show=True, top=30)
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="470px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 20. Full Dashboard: Bar + Line + Toolbox + DataZoom
#
# Combine everything: dual-axis, toolbox (save as image), and data zoom slider.

# %%
np.random.seed(2026)
months_full = pd.date_range("2024-01", periods=24, freq="MS").strftime("%b %Y").tolist()

df_kpi = pd.DataFrame({
    "Month": months_full,
    "Revenue": np.cumsum(np.random.normal(50, 15, 24)).clip(100).tolist(),
})

df_margin = pd.DataFrame({
    "Month": months_full,
    "Margin": (np.random.uniform(15, 35, 24)).tolist(),
})

fig = ec.figure(renderer="svg", height="550px", style=ec.StylePreset.KPI_REPORT)
fig.bar(df_kpi, x="Month", y="Revenue", labels=False, border_radius=4)
fig.plot(df_margin, x="Month", y="Margin", smooth=True, axis=1,
         line_width=3, symbol_size=8)
fig.title("KPI Dashboard: Revenue & Margin", subtitle="Jan 2024 – Dec 2025")
fig.ylabel("Cumulative Revenue ($K)")
fig.ylabel_right("Margin %")
fig.toolbox()
fig.legend(top=50)
fig.datazoom()
fig.margins(top=40)
fig.save(name="kpi_dashboard")
fig.show()
# Out:
# C:\Users\astro\AppData\Local\Temp\ipykernel_48064\1150084960.py:26: OverlapWarning: 24 x-axis categories (avg length 8, fill ratio 2.5×) — auto-rotating labels to 45°. Suppress with ec.config(overlap_warnings=False) or set explicitly with fig.xlabel(rotate=0).
#   fig.show()
# <iframe src="data:text/html;base64,..." width="100%" height="570px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 21. Animated Timeline — Bar Race
#
# Use `TimelineFigure` to create animated charts with a playback slider.
# Each unique value in `time_col` becomes an animation frame.

# %%
np.random.seed(1)
years = ["2020", "2021", "2022", "2023", "2024"]
countries = ["USA", "China", "Germany", "Japan", "India"]

rows = []
for i, yr in enumerate(years):
    for c in countries:
        base = {"USA": 21, "China": 15, "Germany": 4, "Japan": 5, "India": 3}[c]
        gdp = base + i * np.random.uniform(0.3, 1.5) + np.random.normal(0, 0.5)
        rows.append({"Year": yr, "Country": c, "GDP": round(gdp, 2)})

df_gdp = pd.DataFrame(rows)

fig = ec.TimelineFigure(renderer="svg", height="500px", interval=1.5)
fig.bar(df_gdp, x="Country", y="GDP", time_col="Year", labels=True)
fig.title("GDP by Country")
fig.ylabel("GDP (Trillion USD)")
fig.legend(top=30)
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="520px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 22. Animated Timeline — Pie Chart Evolution
#
# Timeline works with pie charts too — watch market share shift over time.

# %%
df_share = pd.DataFrame({
    "Quarter": ["Q1 2024"] * 4 + ["Q2 2024"] * 4 + ["Q3 2024"] * 4 + ["Q4 2024"] * 4,
    "Product": ["Widget A", "Widget B", "Widget C", "Widget D"] * 4,
    "Revenue": [40, 30, 20, 10,
                35, 32, 22, 11,
                28, 35, 25, 12,
                25, 38, 24, 13]
})

fig = ec.TimelineFigure(renderer="svg", height="500px", interval=2.0)
fig.pie(df_share, names="Product", values="Revenue", time_col="Quarter")
fig.title("Product Revenue Share")
fig.legend(top=40)
fig.margins(bottom=50)
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="520px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 22b. Animated Timeline — Histogram
#
# Watch how a distribution shifts over time. Uses global bin edges so
# bins are directly comparable across frames. *(See cell 68 below for the code.)*

# %% [markdown]
# ---
# ## 23. Export to HTML
#
# Any chart can be exported to a standalone HTML file — fully interactive,
# no server required. Great for sharing via email or embedding in reports.

# %%
fig = ec.figure(renderer="svg", height="500px")
fig.bar(df_revenue, x="Quarter", y="Revenue", hue="Region", stack=True)
fig.title("Revenue Report")
fig.ylabel("Revenue ($K)")
fig.legend(top=40)
fig.toolbox()

# Export to file (returns the file path)
path = fig.to_html("revenue_report.html")
print(f"Chart exported to: {path}")
print(f"Open in browser to interact with the chart!")
# Out:
# Chart saved to C:\Users\astro\Documents\Projects\Echartslib\revenue_report.html
# Chart exported to: revenue_report.html
# Open in browser to interact with the chart!

# %% [markdown]
# ---
# ## 24. Inspect the Raw ECharts Option
#
# Use `.to_option()` to get the raw ECharts config dictionary.
# Useful for debugging or passing to other ECharts tools.

# %%
import json

fig = ec.figure(renderer="svg")
fig.bar(df_fruit, x="Fruit", y="Sales")
fig.title("Fruit Sales")

option = fig.to_option()
print(json.dumps(option, indent=2)[:1000], "...")
# Out:
# {
#   "title": {
#     "text": "Fruit Sales",
#     "left": "center",
#     "textStyle": {
#       "fontSize": 16,
#       "fontFamily": "sans-serif"
#     }
#   },
#   "color": [
#     "#5470C6",
#     "#91CC75",
#     "#FAC858",
#     "#EE6666",
#     "#73C0DE",
#     "#3BA272",
#     "#FC8452",
#     "#9A60B4",
#     "#EA7CCC"
#   ],
#   "tooltip": {
#     "trigger": "axis",
#     "axisPointer": {
#       "type": "cross"
#     },
#     "confine": true,
#     "appendTo": "body"
#   },
#   "legend": {
#     "data": [
#       "Sales"
#     ]
#   },
#   "grid": {
#     "left": 70,
#     "right": 70,
#     "top": 60,
#     "bottom": 50,
#     "containLabel": true
#   },
#   "xAxis": {
#     "type": "category",
#     "data": [
#       "Apples",
#       "Bananas",
#       "Cherries",
#       "Dates",
#       "Elderberries"
#     ],
#     "axisLabel": {
#       "rotate": 0,
#       "fontSize": 12,
#       "color": "#666"
#     },
#     "axisTick": {
#       "show": false
#     }
#   },
# ...

# %% [markdown]
# ---
# ## Composite Charts
# The following examples show how to combine multiple chart types in a
# single figure. Simply call `.pie()` with a `center` and `radius` on
# any existing figure to overlay a pie chart — no escape hatches needed.
#
# For advanced cases, `.raw_series({...})` is still available to inject
# any arbitrary ECharts series config.

# %% [markdown]
# ---
# ## 25. Bar Chart with Pie Overlay
#
# A small pie chart positioned in the corner of a bar chart, showing
# the proportional breakdown while the bars show absolute values.

# %%
df_dept = pd.DataFrame({
    "Department": ["Engineering", "Marketing", "Sales", "Design", "Support"],
    "Budget": [450, 280, 320, 180, 120],
})

ec.config(engine='jupyter',adaptive='auto')
# Build a bar chart, then overlay a mini pie in the top-right corner
fig = ec.figure(renderer="svg", height="500px", style=ec.StylePreset.MINIMAL)
fig.bar(df_dept, x="Department", y="Budget", border_radius=6,
        gradient=True, gradient_colors=["#f4f1de","#e07a5f"], 
        labels=True,label_color='orange', 
        emphasis=ec.Emphasis(focus='self'))
fig.title("Department Budgets ($K)")
fig.ylabel("Budget ($K)")
fig.pie(df_dept, names="Department", values="Budget",
        center=["82%", "25%"], radius=["18%", "28%"],
        border_radius=4, label_font_size=9,)
fig.legend(top=40, left=200)
fig.margins(right=120)
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="520px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 26. Bar + Line + Pie (Triple Composite)
#
# Revenue bars on the left axis, growth line on the right axis, and a
# donut showing the product mix — all in one figure.

# %%
df_monthly = pd.DataFrame({
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
    "Revenue": [250, 310, 280, 400, 520, 480],
})
df_growth = pd.DataFrame({
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
    "Growth": [5.2, 8.1, 6.5, 12.3, 18.7, 15.0],
})

df_mix = pd.DataFrame({
    "Plan": ["Enterprise", "Pro", "Starter", "Free-trial"],
    "Share": [45, 30, 15, 10],
})

fig = ec.figure(renderer="svg", height="550px")
# Bar: revenue on left axis
fig.bar(df_monthly, x="Month", y="Revenue", labels=True, border_radius=4)
# Line: growth % on right axis
fig.plot(df_growth, x="Month", y="Growth", smooth=True, axis=1,
         line_width=3, symbol_size=8)
# Pie: product mix overlay in top-right
fig.pie(df_mix, names="Plan", values="Share",
        center=["25%", "32%"], radius=["15%", "25%"],
        border_radius=4, label_font_size=9)
fig.title("Monthly KPIs: Revenue, Growth & Product Mix")
fig.ylabel("Revenue ($K)")
fig.ylabel_right("Growth %")
fig.legend(top=40, left=350)
fig.margins(right=20)
fig.to_html(filepath='./Monthly KPIS Revenue Growth Product Mix.html')
fig.show()
# Out:
# Chart saved to C:\Users\astro\Documents\Projects\Echartslib\Monthly KPIS Revenue Growth Product Mix.html
# <iframe src="data:text/html;base64,..." width="100%" height="570px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 27. Side-by-Side Pies (Multi-Pie Layout)
#
# Two pie charts in one figure, each positioned at different `center` points.

# %%
df_q1 = pd.DataFrame({
    "Product": ["Product A", "Product B", "Product C"],
    "Revenue": [40, 35, 25],
})
df_q2 = pd.DataFrame({
    "Product": ["Product A", "Product B", "Product C"],
    "Revenue": [30, 42, 28],
})

fig = ec.figure(renderer="svg", height="450px")
fig.pie(df_q1, names="Product", values="Revenue",
        center=["28%", "55%"], radius=["25%", "40%"],
        border_radius=6, label_font_size=10)
fig.pie(df_q2, names="Product", values="Revenue",
        center=["72%", "55%"], radius=["25%", "40%"],
        border_radius=6, label_font_size=10)
fig.title("Product Mix: Q1 vs Q2")
fig.extra(
    legend={"data": ["Product A", "Product B", "Product C"],
            "top": 40, "left": "center"},
    graphic=[
        {"type": "text", "left": "18%",  "top": "88%",
         "style": {"text": "Q1 2025", "fontSize": 14, "fontWeight": "bold",
                    "fill": "#888"}},
        {"type": "text", "left": "62%", "top": "88%",
         "style": {"text": "Q2 2025", "fontSize": 14, "fontWeight": "bold",
                    "fill": "#888"}},
    ],
)
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="470px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 28. Stacked Bar with Line Trend + Pie Breakdown
#
# A common dashboard pattern: stacked bars by region, a total-trend line,
# and a pie summarizing the overall split.

# %%
df_rev = pd.DataFrame({
    "Quarter": ["Q1", "Q2", "Q3", "Q4"] * 3,
    "Revenue": [120, 145, 160, 180, 90, 110, 130, 155, 60, 80, 95, 110],
    "Region":  ["North"] * 4 + ["South"] * 4 + ["West"] * 4,
})

# Compute totals for the trend line
df_totals = df_rev.groupby("Quarter", sort=False)["Revenue"].sum().reset_index()
df_totals.columns = ["Quarter", "Total"]

# Compute region totals for the pie
region_totals = (df_rev.groupby("Region")["Revenue"].sum()
                 .reset_index()
                 .rename(columns={"Revenue": "Total"}))

fig = ec.figure(renderer="svg", height="550px")
# Stacked bars by region
fig.bar(df_rev, x="Quarter", y="Revenue", hue="Region",
        stack=True, border_radius=4)
# Total trend line on right axis
fig.plot(df_totals, x="Quarter", y="Total", smooth=True, axis=1,
         line_width=3, symbol_size=10, labels=True)
# Mini pie showing region split
fig.pie(region_totals, names="Region", values="Total",
        center=["26%", "20%"], radius=["12%", "22%"],
        border_radius=4, label_font_size=9)
fig.title("Quarterly Revenue: Stacked + Trend + Breakdown")
fig.ylabel("Revenue ($K)")
fig.ylabel_right("Total ($K)")
fig.margins(right=120)
fig.legend(top=35)
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="570px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
#
# That covers the full API — from simple single-series charts all the way to
# composite multi-chart layouts, animated timelines, candlestick stock dashboards,
# and dashboard-style figures.
# Every chart is fully interactive: hover for tooltips, click legend items to
# toggle series, and use the toolbox to save as PNG/SVG.
#
# **Key methods for composites:** `.pie()` accepts `center` and `radius`
# to overlay a pie on any chart. `.candlestick()` composes naturally with
# `.plot()` (moving averages) and `.bar()` (volume) on dual axes.
# For advanced cases, `.raw_series({...})` is still available as an escape hatch.

# %% [markdown]
# ## Emphasis Examples
#
# The `emphasis` parameter lets you control hover/highlight behavior using typed Python attributes instead of raw dictionaries.

# %%
from echartsy import Emphasis, ItemStyle

df_heat = pd.DataFrame({
    "Day": ["Mon", "Tue", "Wed", "Thu", "Fri"] * 3,
    "Hour": ["9am"] * 5 + ["12pm"] * 5 + ["5pm"] * 5,
    "Value": [10, 20, 30, 25, 15, 35, 40, 50, 45, 30, 20, 25, 35, 30, 10],
})

(
    ec.Figure(renderer="svg", height="400px")
    .heatmap(
        df_heat, x="Day", y="Hour", value="Value",
        emphasis=Emphasis(
            item_style=ItemStyle(border_color="#000", border_width=2, shadow_blur=15),
        ),
    )
    .title("Heatmap — Custom Hover Border")
    .show()
)
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="420px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %%
from echartsy.emphasis import ScatterEmphasis

df_scatter = pd.DataFrame({
    "Height": [160, 165, 170, 175, 180, 185, 155, 172, 168, 190],
    "Weight": [55, 62, 68, 72, 78, 85, 50, 70, 65, 90],
})

(
    ec.Figure(renderer="svg", height="400px")
    .scatter(
        df_scatter, x="Height", y="Weight",
        emphasis=ScatterEmphasis(disabled=False),
    )
    .title("Scatter — Emphasis Disabled")
    .xlim(150,200)
    .show()
)
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="420px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %%
from echartsy.emphasis import PieEmphasis, LabelStyle

df_pie = pd.DataFrame({
    "Category": ["Electronics", "Clothing", "Food", "Books"],
    "Amount": [450, 300, 250, 150],
})

(
    ec.Figure(renderer="svg", height="400px")
    .pie(
        df_pie, names="Category", values="Amount",
        emphasis=PieEmphasis(
            scale=True,
            scale_size=15,
            item_style=ItemStyle(shadow_blur=20, shadow_color="rgba(0,0,0,0.6)"),
            label=LabelStyle(show=True, font_size=16, font_weight="bold"),
        ),
    )
    .title("Pie Emphasis — Scale on Hover")
    .show()
)
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="420px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %%
from echartsy.emphasis import LineEmphasis, LineStyle, LabelStyle

df_line = pd.DataFrame({
    "Date": ["Q1", "Q2", "Q3", "Q4"] * 2,
    "Price": [150, 180, 170, 200, 90, 110, 130, 120],
    "Stock": ["AAPL"] * 4 + ["GOOG"] * 4,
})

(
    ec.Figure(renderer="svg", height="400px")
    .plot(
        df_line, x="Date", y="Price", hue="Stock",
        emphasis=LineEmphasis(
            focus="series",
            line_style=LineStyle(width=4),
            label=LabelStyle(show=True, formatter="{c}"),
        ),
    )
    .title("Line Emphasis — Bold on Hover")
    .show()
)
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="420px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %%
from echartsy.emphasis import Emphasis, ItemStyle

df_bar = pd.DataFrame({
    "Month": ["Jan", "Feb", "Mar", "Apr"] * 2,
    "Revenue": [100, 120, 140, 130, 80, 90, 110, 100],
    "Region": ["East"] * 4 + ["West"] * 4,
})

(
    ec.Figure(renderer="svg", height="400px")
    .bar(
        df_bar, x="Month", y="Revenue", hue="Region",
        emphasis=Emphasis(
            focus="series",
            item_style=ItemStyle(shadow_blur=10, shadow_color="rgba(0,0,0,0.3)"),
        ),
    )
    .title("Bar Emphasis — Focus on Series")
    .legend(top=50)
    .show()
)
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="420px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %%
np.random.seed(42)
df_exam = pd.DataFrame({
    "Score": np.concatenate([
        np.random.normal(65, 12, 200),   # 2022: lower average
        np.random.normal(72, 10, 200),   # 2023: improving
        np.random.normal(78, 8, 200),    # 2024: higher average, tighter spread
    ]),
    "Year": ["2022"] * 200 + ["2023"] * 200 + ["2024"] * 200,
})

fig = ec.TimelineFigure(renderer="svg", height="450px", interval=2.0)
fig.hist(df_exam, column="Score", time_col="Year", bins=15, labels=True)
fig.title("Exam Score Distribution Over Time")
fig.ylabel("Count")
fig.to_html(filepath='./Exam Score.html')
fig.show()
# Out:
# Chart saved to C:\Users\astro\Documents\Projects\Echartslib\Exam Score.html
# <iframe src="data:text/html;base64,..." width="100%" height="470px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## Axis Pointer Styling
#
# Customize how the tooltip's axis pointer looks — change colors, widths,
# and dash types for line, cross, and shadow pointers. Use `axis_pointer()`
# for global configuration or pass styling params directly to `tooltip()`.

# %%
# Style the tooltip's cross pointer with red cross-hairs
fig = ec.figure(renderer="svg", height="450px")
fig.bar(df_revenue, x="Quarter", y="Revenue", hue="Region")
fig.tooltip(trigger="axis", pointer="cross",
            cross_color="#e74c3c", cross_width=2, cross_type="dashed")
fig.title("Cross Pointer — Red Dashed")
fig.ylabel("Revenue ($K)")
fig.legend(top=40)
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="470px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %%
# Global axis pointer with shadow + snap + label
fig = ec.figure(renderer="svg", height="450px")
fig.plot(df_temp, x="Month", y="Temperature", smooth=True, area=True)
fig.axis_pointer(type="shadow", snap=True, label=True,
                 shadow_color="rgba(150,150,150,0.15)")
fig.title("Shadow Pointer with Snap & Label")
fig.ylabel("Temp (°C)")

fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="470px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## Streamlit Dark Mode (Auto-Detection)
#
# When using `engine="streamlit"`, echartsy automatically detects the Streamlit
# app's theme and adapts chart colours accordingly. No configuration needed —
# it just works.
#
# ```python
# # Auto-adapts to Streamlit's theme (dark or light)
# ec.config(engine="streamlit")
#
# # Force dark mode regardless of Streamlit theme
# ec.config(engine="streamlit", adaptive="dark")
#
# # Force light mode
# ec.config(engine="streamlit", adaptive="light")
# ```
#
# The adaptive system patches text colours, grid lines, titles, and backgrounds
# so charts look great in both light and dark Streamlit apps.

# %% [markdown]
# ---
# ## 29. Candlestick Chart — Stock Dashboard
#
# A full stock-chart layout: OHLC candlestick with a 5-day moving average line,
# Bollinger Bands as shaded area, and volume bars on a secondary axis.
# Combines `.candlestick()`, `.plot()`, and `.bar()` in one figure.

# %%
np.random.seed(2026)

# --- Generate 30 trading days of realistic OHLC data ---
n_days = 30
dates = pd.bdate_range("2025-06-01", periods=n_days).strftime("%b %d").tolist()
price = 150.0
rows = []
for d in dates:
    open_ = round(price + np.random.normal(0, 1.5), 2)
    close_ = round(open_ + np.random.normal(0.3, 3), 2)
    high_ = round(max(open_, close_) + abs(np.random.normal(0, 2)), 2)
    low_ = round(min(open_, close_) - abs(np.random.normal(0, 2)), 2)
    vol = int(np.random.lognormal(11.5, 0.4))
    rows.append({"Date": d, "Open": open_, "Close": close_,
                 "Low": low_, "High": high_, "Volume": vol})
    price = close_

df_stock = pd.DataFrame(rows)

# Moving average & Bollinger Bands
df_stock["MA5"] = df_stock["Close"].rolling(5).mean().round(2)
df_stock["Upper"] = (df_stock["MA5"] + 2 * df_stock["Close"].rolling(5).std()).round(2)
df_stock["Lower"] = (df_stock["MA5"] - 2 * df_stock["Close"].rolling(5).std()).round(2)

# Drop NaN rows for the overlay lines (first 4 days have no MA5)
df_ma = df_stock.dropna(subset=["MA5"])

fig = ec.figure(renderer="svg", height="600px")

# Candlestick: OHLC prices
fig.candlestick(df_stock, date="Date", open="Open", close="Close",
                low="Low", high="High",
                up_color="#00DA3C", down_color="#EC0000",
                up_border="#008F28", down_border="#8A0000")

# Moving average line
fig.plot(df_ma, x="Date", y="MA5", smooth=True, line_width=2,
         symbol_size=0, name="MA5")

# Bollinger upper & lower bands as thin dashed lines
fig.plot(df_ma, x="Date", y="Upper", smooth=True, line_width=1,
         symbol_size=0, name="Upper Band", lineStyle={"type": "dashed"})
fig.plot(df_ma, x="Date", y="Lower", smooth=True, line_width=1,
         symbol_size=0, name="Lower Band", lineStyle={"type": "dashed"})

# Volume bars on secondary axis
fig.bar(df_stock, x="Date", y="Volume", axis=1, bar_width="60%",
        name="Volume")

fig.title("ACME Corp — 30-Day Stock Dashboard",
          subtitle="Candlestick + MA5 + Bollinger Bands + Volume")
fig.ylabel("Price ($)")
fig.ylabel_right("Volume")
fig.ylim(0, max(df_stock["Volume"]) * 4, axis=1)  # shrink volume bars
fig.legend(top=50)
fig.margins(top=80)
fig.datazoom(start=0, end=100)
fig.toolbox()
fig.show()
# Out:
# C:\Users\astro\AppData\Local\Temp\ipykernel_48064\266471607.py:59: OverlapWarning: 30 x-axis categories (avg length 6, fill ratio 2.4×) — auto-rotating labels to 45°. Suppress with ec.config(overlap_warnings=False) or set explicitly with fig.xlabel(rotate=0).
#   fig.show()
# <iframe src="data:text/html;base64,..." width="100%" height="620px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 30. Gauge Chart
#
# A speedometer-style indicator — perfect for KPIs and dashboards.
# Customize the arc colours to indicate thresholds (green/yellow/red).

# %%
fig = ec.figure(renderer="svg", height="400px")
fig.gauge(72, name="CPU Usage",
          min_val=0, max_val=100, split_number=10,
          axis_line_colors=[
              (0.3, "#67e0e3"),   # green zone: 0–30%
              (0.7, "#37a2da"),   # blue zone: 30–70%
              (1.0, "#fd666d"),   # red zone: 70–100%
          ])
fig.title("Server CPU Usage")
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="420px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 31. Sunburst Chart
#
# Hierarchical data as concentric rings — a radial version of treemap.
# Uses the same `path` + `value` API as `.treemap()`.

# %%
df_org = pd.DataFrame({
    "Region":   ["Americas", "Americas", "Americas", "EMEA", "EMEA", "EMEA", "APAC", "APAC"],
    "Category": ["Electronics", "Clothing", "Food", "Electronics", "Clothing", "Food", "Electronics", "Food"],
    "Revenue":  [500, 300, 200, 400, 250, 150, 350, 180],
})

fig = ec.figure(renderer="svg", height="500px")
fig.sunburst(df_org, path=["Region", "Category"], value="Revenue",
             inner_radius="20%", sort="desc")
fig.title("Revenue Sunburst: Region → Category")
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="520px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 32. Graph / Network Chart
#
# Nodes and edges — useful for knowledge graphs, dependency trees, or social
# networks. Supports force-directed and circular layouts.

# %%
nodes = pd.DataFrame({
    "name":  ["Alice", "Bob", "Carol", "Dave", "Eve", "Frank"],
    "group": ["Engineering", "Engineering", "Design", "Design", "Marketing", "Marketing"],
})
edges = pd.DataFrame({
    "source": ["Alice", "Alice", "Bob", "Carol", "Dave", "Eve", "Alice"],
    "target": ["Bob",   "Carol", "Dave", "Dave",  "Eve",  "Frank", "Eve"],
})

fig = ec.figure(renderer="svg", height="500px")
fig.graph(nodes, edges, node_category="group",
          layout="force", roam=True, symbol_size=30,
          emphasis=ec.GraphEmphasis(focus="adjacency"))
fig.title("Team Collaboration Network")
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="520px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 33. Calendar Heatmap
#
# GitHub-style contribution grid. Pass a date column and a value column,
# and the year is auto-detected from the data.

# %%
np.random.seed(2025)
dates = pd.date_range("2025-01-01", "2025-12-31", freq="D")
df_commits = pd.DataFrame({
    "Date": dates.strftime("%Y-%m-%d"),
    "Commits": np.random.poisson(3, len(dates)),
})

fig = ec.figure(renderer="svg", height="250px")
fig.calendar_heatmap(df_commits, date="Date", value="Commits",
                     cell_size=["auto", 14],
                     in_range_colors=["#ebedf0", "#9be9a8", "#40c463", "#30a14e", "#216e39"])
fig.title("Contribution Activity — 2025")
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="270px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 34. Annotations — Mark Line, Point & Area
#
# Add reference lines, highlight points, and shaded regions to any series.
# Annotations attach to the most recently added series by default.

# %%
df_sales = pd.DataFrame({
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
              "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"],
    "Revenue": [180, 210, 195, 250, 310, 280,
                320, 350, 290, 260, 300, 380],
})

fig = ec.figure(renderer="svg", height="500px")
fig.plot(df_sales, x="Month", y="Revenue", smooth=True,
         area=True, area_opacity=0.1, line_width=3)

# Horizontal target line
fig.mark_line(y=300, label="Target", color="#e74c3c", line_dash="dashed")

# Vertical launch marker
fig.mark_line(x="May", label="Product Launch", color="#2ecc71")

# Highlight the peak
fig.mark_point(type="max", label="Peak")

# Shaded "holiday season" band
fig.mark_area(x_range=["Oct", "Dec"], color="rgba(255,165,0,0.15)")

fig.title("2025 Revenue with Annotations")
fig.ylabel("Revenue ($K)")
fig.legend(top=40)
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="520px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 35. Subplots (Multi-Grid)
#
# Use `rows` to create vertically stacked panels — each with independent
# axes and categories. Link them with `datazoom(grids=[0, 1])` for
# synchronized scrolling.

# %%
# Reuse df_stock from example 29 (candlestick)
fig = ec.figure(renderer="svg", height="600px", rows=2, row_heights=["70%", "30%"])

# Top panel: price line
fig.plot(df_stock, x="Date", y="Close", smooth=True, line_width=2, grid=0)
fig.plot(df_ma, x="Date", y="MA5", smooth=True, line_width=1,
         symbol_size=0, grid=0)

# Bottom panel: volume bars
fig.bar(df_stock, x="Date", y="Volume", grid=1, bar_width="60%")

fig.title("Stock Price & Volume (Subplots)")
fig.datazoom(grids=[0, 1])  # linked zoom across both panels
fig.legend(top=40)
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="620px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 36. Simple Subplot — Line on Top, Bar on Bottom
#
# A beginner-friendly two-row layout: a line chart tracking monthly
# temperature on top and a bar chart showing rainfall on the bottom.
# Each grid has its own independent y-axis.

# %%
# --- Example 36: Simple two-row subplot ---
import echartsy as ec
import pandas as pd
import numpy as np

ec.config(engine="jupyter")

months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
          "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

df_weather = pd.DataFrame({
    "Month": months,
    "Temperature": [3, 5, 10, 15, 20, 25, 28, 27, 22, 15, 9, 4],
    "Rainfall": [48, 40, 52, 60, 70, 55, 35, 38, 50, 65, 58, 50],
})

fig = ec.figure(renderer="svg", height="550px", rows=2, row_heights=["55%", "45%"])

# Top panel: temperature line
fig.plot(df_weather, x="Month", y="Temperature", smooth=True,
         line_width=3, area=True, area_opacity=0.15, grid=0)

# Bottom panel: rainfall bars
fig.bar(df_weather, x="Month", y="Rainfall", grid=1,
        border_radius=4, labels=True)

fig.title("Monthly Weather: Temperature & Rainfall")
fig.legend(top=40)
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="570px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 37. Stock Dashboard Subplot — Candlestick + Volume with Linked Zoom
#
# A sophisticated two-grid financial dashboard: the top grid (70 %) shows a
# candlestick chart with a 5-day moving-average overlay and horizontal
# mark-line annotations; the bottom grid (30 %) shows volume bars.
# A linked `datazoom` lets you scroll both panels simultaneously.

# %%
# --- Example 37: Stock dashboard subplot (candlestick + volume) ---
import echartsy as ec
import pandas as pd
import numpy as np

ec.config(engine="jupyter")

np.random.seed(100)
n_days = 60
dates = pd.bdate_range("2025-01-02", periods=n_days).strftime("%b %d").tolist()

price = 220.0
rows = []
for d in dates:
    open_ = round(price + np.random.normal(0, 2), 2)
    close_ = round(open_ + np.random.normal(0.15, 3.5), 2)
    high_ = round(max(open_, close_) + abs(np.random.normal(0, 2.5)), 2)
    low_ = round(min(open_, close_) - abs(np.random.normal(0, 2.5)), 2)
    vol = int(np.random.lognormal(12, 0.5))
    rows.append({"Date": d, "Open": open_, "Close": close_,
                 "Low": low_, "High": high_, "Volume": vol})
    price = close_

df_stk = pd.DataFrame(rows)
df_stk["MA5"] = df_stk["Close"].rolling(5).mean().round(2)
df_stk["MA20"] = df_stk["Close"].rolling(20).mean().round(2)
df_ma5 = df_stk.dropna(subset=["MA5"])
df_ma20 = df_stk.dropna(subset=["MA20"])

fig = ec.figure(renderer="svg", height="650px", rows=2, row_heights=["70%", "30%"])

# --- Top grid: candlestick + moving averages ---
fig.candlestick(df_stk, date="Date", open="Open", close="Close",
                low="Low", high="High",
                up_color="#26A69A", down_color="#EF5350",
                up_border="#1B8A6B", down_border="#C62828", grid=0)

fig.plot(df_ma5, x="Date", y="MA5", smooth=True, line_width=1.5,
         symbol_size=0, name="MA 5", grid=0)
fig.plot(df_ma20, x="Date", y="MA20", smooth=True, line_width=1.5,
         symbol_size=0, name="MA 20", grid=0)

# Annotations on the price panel
fig.mark_line(y=round(df_stk["Close"].mean(), 1), label="Avg Close",
              color="#FF9800", line_dash="dashed")
fig.mark_point(type="max", label="High")

# --- Bottom grid: volume bars ---
fig.bar(df_stk, x="Date", y="Volume", grid=1, bar_width="70%", name="Volume")

fig.title("BETA Inc. — 60-Day Stock Dashboard",
          subtitle="Candlestick + MA5/MA20 + Volume (linked zoom)")
fig.legend(top=50)
fig.margins(top=80)
fig.datazoom(grids=[0, 1], start=30, end=80)
fig.toolbox()
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="670px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 38. Multi-Metric Dashboard — Dual-Axis Line + Stacked Bar Subplot
#
# An advanced two-grid dashboard: the top grid (60 %) shows a dual-axis
# line chart with revenue and profit margin plotted against left and right
# y-axes; the bottom grid (40 %) shows a stacked bar chart of cost
# breakdown by category. Includes linked datazoom, custom legend placement,
# and mark-line annotations.

# %%
# --- Example 38: Multi-metric dashboard subplot ---
import echartsy as ec
import pandas as pd
import numpy as np

ec.config(engine="jupyter")

np.random.seed(55)
months = pd.date_range("2024-01", periods=12, freq="MS").strftime("%b %Y").tolist()

# Top grid data: revenue and profit margin (two related metrics)
base_rev = np.array([180, 210, 195, 240, 275, 310, 290, 330, 360, 340, 380, 420])
noise = np.random.normal(0, 10, 12)
revenue = np.round(base_rev + noise, 1)
margin = np.round(np.random.uniform(18, 35, 12), 1)

df_top = pd.DataFrame({
    "Month": months,
    "Revenue": revenue,
    "Margin": margin,
})

# Bottom grid data: cost breakdown (stacked bar)
df_costs = pd.DataFrame({
    "Month": months * 3,
    "Cost": np.concatenate([
        np.round(np.random.uniform(40, 80, 12), 1),   # COGS
        np.round(np.random.uniform(20, 50, 12), 1),   # Marketing
        np.round(np.random.uniform(15, 35, 12), 1),   # Operations
    ]),
    "Category": ["COGS"] * 12 + ["Marketing"] * 12 + ["Operations"] * 12,
})

fig = ec.figure(renderer="svg", height="700px", rows=2, row_heights=["60%", "40%"])

# --- Top grid: dual-axis line chart ---
fig.plot(df_top, x="Month", y="Revenue", smooth=True, line_width=3,
         area=True, area_opacity=0.1, labels=True, grid=0, name="Revenue ($K)")
fig.plot(df_top, x="Month", y="Margin", smooth=True, line_width=2,
         symbol_size=6, axis=1, grid=0, name="Margin (%)")

# Mark the revenue target line
fig.mark_line(y=300, label="Revenue Target", color="#e74c3c",
              line_dash="dashed", series_index=0)
# Highlight the best margin month
fig.mark_point(type="max", label="Best Margin", series_index=1)

# --- Bottom grid: stacked bar chart ---
fig.bar(df_costs, x="Month", y="Cost", hue="Category",
        stack=True, border_radius=3, grid=1)

fig.title("2024 Business Dashboard",
          subtitle="Revenue & Margin (top) | Cost Breakdown (bottom)")
fig.ylabel("Revenue ($K)")
fig.ylabel_right("Margin %")
fig.legend(top=50,left=10)
fig.margins(top=180)
fig.datazoom(grids=[0, 1])
fig.toolbox()
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="720px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 36. Horizontal Bar Shortcut & Log Scale
#
# `barh()` is a matplotlib-style shortcut for `bar(orient="h")`.
# Use `yscale("log")` or `ylim(scale="log")` for logarithmic axes.

# %%
# barh() shortcut
df_lang = pd.DataFrame({
    "Language": ["Python", "JavaScript", "Java", "C++", "Go", "Rust"],
    "Stars": [85000, 62000, 45000, 38000, 28000, 22000],
})

fig = ec.figure(renderer="svg", height="400px")
fig.barh(df_lang, x="Language", y="Stars", labels=True, border_radius=6)
fig.title("GitHub Stars by Language (barh)")
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="420px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %%
# Log scale axis
df_exp = pd.DataFrame({
    "Year": ["2015", "2016", "2017", "2018", "2019", "2020", "2021", "2022", "2023", "2024"],
    "Users": [100, 250, 800, 2500, 8000, 25000, 80000, 250000, 800000, 2500000],
})

fig = ec.figure(renderer="svg", height="400px")
fig.plot(df_exp, x="Year", y="Users", smooth=True, labels=True,
         area=True, area_opacity=0.1)
fig.yscale("log")
fig.title("User Growth (Log Scale)")
fig.ylabel("Users (log)")
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="420px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 37. Visual Map
#
# Expose the ECharts `visualMap` component for colour-mapped legends.
# Works with continuous gradients or discrete piecewise ranges.

# %%
np.random.seed(42)
df_perf = pd.DataFrame({
    "Team": [f"Team {chr(65+i)}" for i in range(10)],
    "Score": np.random.randint(30, 100, 10),
})

fig = ec.figure(renderer="canvas", height="400px")
fig.bar(df_perf, x="Team", y="Score", labels=True, border_radius=4)
fig.visual_map(min_val=30, max_val=100,
               colors=["#d73027", "#fee08b", "#1a9850"],
               position="right")
fig.title("Team Performance (Colour-Mapped)")
fig.save()
fig.show()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="420px" style="border:none; overflow:hidden;" sandbox="allow-scripts allow-same-origin allow-downloads"></iframe>

# %% [markdown]
# ---
# ## 38. Figure Summary & Inspection
#
# Use `fig.summary()` to get a human-readable overview of the figure state,
# and `repr(fig)` for a compact one-liner. Great for debugging.

# %%
df_demo = pd.DataFrame({
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
    "Revenue": [250, 310, 280, 400, 520, 480],
    "Margin": [15.2, 18.1, 16.5, 22.3, 28.7, 25.0],
})

fig = ec.figure(renderer="svg", height="500px")
fig.bar(df_demo, x="Month", y="Revenue")
fig.plot(df_demo, x="Month", y="Margin", axis=1, smooth=True)
fig.title("Revenue & Margin")
fig.ylabel("Revenue ($K)")
fig.ylabel_right("Margin %")

# Compact repr
print(repr(fig))
print()

# Full summary
fig.summary()
# Out:
# <Figure series=2, height='500px', mode='cartesian', title='Revenue & Margin'>
#
# Figure(height='500px', renderer='svg')
#   Series: 2
#     [0] bar        — name='Revenue'
#     [1] line       — name='Margin', axis=1
#   Title: 'Revenue & Margin'
#   Axes: left='Revenue ($K)', right='Margin %'
# "Figure(height='500px', renderer='svg')\n  Series: 2\n    [0] bar        — name='Revenue'\n    [1] line       — name='Margin', axis=1\n  Title: 'Revenue & Margin'\n  Axes: left='Revenue ($K)', right='Margin %'"
